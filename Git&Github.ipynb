# %% [markdown]
# ###1)configure

# %%
1)git config --global use.name "My Name"
2)git config --global user.email "someone@email.com"
3)git config --list

# %% [markdown]
# ###2)Clone & Status

# %%
1)clone - Cloning a repository on our local machine
 git clone <-some link->

2)status - display the state of the code
  git status

  A)untracked - new files that git doesn't yet track
  B)modified - changed
  C)staged - file is ready to be committed
  D)unmodified - unchanged

3)ls -Force - To see hidden files

# %%
remote                   local
[github]                  [pc]

# %% [markdown]
# ###3)git

# %%
1)git init(working directory)-make folder to git repository

2)add-addss new or changed files in your
-------
  git add file.txt(single file)
  git add file1.txt file2.txt file3.txt(multiple file)
  git add .(all file)

3)commit-it is record of changes
-------
  git commit -m "Some message"

# %% [markdown]
# ###4)Push

# %%
Push - opload local repo content to remote repo
-----
git push origin main

# %% [markdown]
# ![Screenshot 2024-09-02 175711.png](data:image/png;base64,...)

# %%
"""
Process from local machine to git to github
--------------------------------------------

1)git init -used to create a new git repo

2)Git remote add origin <-link->

3)git remote -v (to verify remote)

4)git branch (to check branch)

5)git branch -M main (to rename branch)

6)git push origin main"""

# %% [markdown]
# ###5)Git Branches

# %%
"""
1)git branch (to check branch)
2)git branch bug-fix
3)git switch bug-fix
4)log
5)switch master
6)switch -c dark-mode
7)checkout orange-mode

-----------
1)git branch   (to check branch)
2)git branch -M main (to rename branch)
3)git checkout main (to go in main master table)
4)git cheout <-branch name) (go from one branch to other branch)
3)git checkout -b <-new branch name-> (to create new branch)
4)git branch -d <-branch name-> (to delete branch) """

# %% [markdown]
# ###6)Merging Code

# %%
way 1
------
1)git diff <-branch name->
2)git merge <-branch name->

way 2-pull request-it lets you tell others about changes you have pushed to a branch in a repository on GitHub
-------

# %% [markdown]
# ###7)Pull Command

# %%
1)git pull origin main - used to fetch and download content from a remote repo and immediatelly update the local repo to match that content

# %% [markdown]
# ###8)Undoing Changes

# %%
cas1 : staged changes
     git reset <-file name-> (sinle file)
     git reset (all file)

case2 : commited changes (for one commit)
    git reset HEAD~1

case3 : commited changes (for many commits)
 git reset <-commit hash->
 git reset --hard <-commit hash->
